# %% [markdown]
# ### Import libraries and connect with database

# %%
import matplotlib.pyplot as plt
import numpy as np
import mysql.connector

connection = mysql.connector.connect(user='root', password='secret',
                              host='mariadb',
                              database='mydb_bdea')
cur = connection.cursor()

# %% [markdown]
# ### Load data from *.csv*-File into table *sleep_data*

# %%
cur.execute("LOAD DATA INFILE '/var/lib/mydb_bdea/sleep_data.csv' INTO TABLE sleep_data FIELDS TERMINATED BY ';' LINES TERMINATED BY '\r\n';")

# %%
import pandas as pd
query = "SELECT startDay, startTime, endDay, endTime, deepSleepSeconds, REMSleepSeconds, unmeasuredSeconds, lowestRespRate, highestRespRate FROM sleep_data;"
df = pd.read_sql(query, connection)
# Out:
# /tmp/ipykernel_1651/842027726.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %% [markdown]
# ### Convert data types

# %%
df["start"] = df['startDay'].astype(str) +"T"+ df["startTime"] # concatenate Day and Time
df["end"] = df['endDay'].astype(str) +"T"+ df["endTime"] # concatenate Day and Time

# %%
df["startDay"] = pd.to_datetime(df["startDay"], errors='coerce') # change datatype into datetime
df["endDay"] = pd.to_datetime(df["endDay"], errors='coerce') # change datatype into datetime

# %%
cols = ["deepSleepSeconds", "REMSleepSeconds", "unmeasuredSeconds", "highestRespRate", "lowestRespRate"]
df[cols] = df[cols].apply(pd.to_numeric) # change datatype into numeric

# %%
df["start"] = pd.to_datetime(df["start"], format='ISO8601', errors='coerce') # change datatype into datetime
df["end"] = pd.to_datetime(df["end"], format='ISO8601', errors='coerce') # change datatype into datetime

# %%
df['startTime'] = pd.to_datetime(df['startTime'],format= '%H:%M:%S') # change datatype into datetime
df['endTime'] = pd.to_datetime(df['endTime'],format= '%H:%M:%S') # change datatype into datetime

# %% [markdown]
# ### Calculate average sleep duration per weekday

# %%
import numpy as np
df['sleepDuration'] = df['end'] - df['start'] # calculate sleepDuration
df['sleepDuration'] = df['sleepDuration'] / np.timedelta64(1, 'h') # convert timedelta datatype in hours
df['weekday'] = df['endDay'].dt.dayofweek # extract weekday
# change numeric weekday in text 
df['weekday'] = df['weekday'].map({0.0: 'Monday', 1.0: 'Tuesday', 2.0: 'Wednesday', 3.0: 'Thursday', 4.0: 'Friday', 5.0: 'Saturday', 6.0: 'Sunday'})

# %%
df_new = pd.DataFrame({'sleepDuration': df['sleepDuration'], 'weekday': df['weekday']}) # create new df
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'] # create cats for ordering weekdays
df_new['weekday'] = pd.Categorical(df_new['weekday'], categories=cats, ordered=True) # order weekdays

df_new = df_new.groupby('weekday').mean() # calculate sleepDuration mean per weekday

ax1 = df_new.plot(kind='bar', figsize=(20, 10), ylabel = 'hours')
ax1.legend(loc=4, fontsize=12)
ax1.set_ylabel('hours',fontdict={'fontsize':16})
ax1.set_xlabel('weekday',fontdict={'fontsize':16})
ax1.set_title('Average sleep duration per weekday', pad=20, fontdict={'fontsize':24})
plt.axhline(y=np.nanmean(df_new['sleepDuration']), color='red', linestyle='--', linewidth=3, label='Avg') # add average line
plt.show()

# %%
df.plot(x="startDay", y=["deepSleepSeconds", "REMSleepSeconds"], figsize=(20, 10))
plt.show()

# %%
df.plot(x="startDay", y="sleepDuration", figsize=(20, 10))
plt.show()

# %%
query = "SELECT overallScore, qualityScore, durationScore, recoveryScore, deepScore, REMScore, lightScore, awakeningsCountScore, awakeTimeScore, combinedAwakeScore, restfulnessScore, interruptionsScore, sleepFeedback  FROM sleep_data;"
df_score = pd.read_sql(query, connection)
# Out:
# /tmp/ipykernel_1651/912382627.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_score = pd.read_sql(query, connection)

# %%
cols = ["overallScore", "qualityScore", "durationScore", "recoveryScore", "deepScore", "REMScore", "lightScore", "awakeningsCountScore", "awakeTimeScore", "combinedAwakeScore", "restfulnessScore", "interruptionsScore"]
df_score[cols] = df_score[cols].apply(pd.to_numeric)

# %% [markdown]
# ### Calculate number of sleeps per feedback

# %%
query = "SELECT sleepFeedback, COUNT(sleepFeedback) as CountFeedback FROM sleep_data group by sleepFeedback;"
df_count = pd.read_sql(query, connection)
df_count.plot(x = 'sleepFeedback', kind='bar')
plt.show()
# Out:
# /tmp/ipykernel_1651/2148969457.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_count = pd.read_sql(query, connection)

# %% [markdown]
# ### Average score per feedback

# %%
query = "SELECT avg(overallScore) as meanScore, sleepFeedback FROM sleep_data group by sleepFeedback order by meanScore desc;"
df_ = pd.read_sql(query, connection)
print(df_.head(10))
# Out:
#    meanScore                 sleepFeedback
# 0  92.333333    POSITIVE_HIGHLY_RECOVERING
# 1  91.000000    POSITIVE_OPTIMAL_STRUCTURE
# 2  86.037037  POSITIVE_LONG_AND_RECOVERING
# 3  83.760000  POSITIVE_LONG_AND_CONTINUOUS
# 4  83.571429  POSITIVE_LONG_AND_REFRESHING
# 5  80.000000                 POSITIVE_DEEP
# 6  78.384615           POSITIVE_RECOVERING
# 7  77.545455    NEGATIVE_LONG_BUT_RESTLESS
# 8  77.000000       NEGATIVE_LONG_BUT_LIGHT
# 9  72.000000           POSITIVE_CONTINUOUS
# /tmp/ipykernel_1593/2366521018.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_ = pd.read_sql(query, connection)

# %%
df_score.groupby('sleepFeedback').mean().plot(kind='bar', figsize=(20, 10))
plt.show()

# %% [markdown]
# ### Sleep score, sleep stress level and heart rate for negative and positive score

# %%
# calculate metrix for negative score
query = "SELECT overallScore, RestingHeartRate, maxAvgHeartRate, AsleepAverageStressLevel, sleepFeedback, insight FROM sleep_data WHERE sleepFeedback LIKE 'NEGATIVE%';"
df_neg = pd.read_sql(query, connection)
cols = ["overallScore", "RestingHeartRate", "maxAvgHeartRate", "AsleepAverageStressLevel"]
df_neg[cols] = df_neg[cols].apply(pd.to_numeric) # change datatype into numeric
df_neg['AsleepAverageStressLevel'] = df_neg['AsleepAverageStressLevel'].mask(df_neg['AsleepAverageStressLevel'] <= 0) # clean data
df_neg["overallSleepScore"] = df_neg["overallScore"]
df_neg.drop(df_neg["overallScore"])
df_neg['RestingHeartRate_Roll'] = df_neg["RestingHeartRate"].rolling(10).mean()
df_neg['AsleepAverageStressLevel_Roll'] = df_neg["AsleepAverageStressLevel"].rolling(10).mean()
df_neg['maxAvgHeartRate_Roll'] = df_neg["maxAvgHeartRate"].rolling(10).mean()
df_neg['overallSleepScore_Roll'] = df_neg["overallScore"].rolling(10).mean()
# Out:
# /tmp/ipykernel_1593/1399026170.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_neg = pd.read_sql(query, connection)

# %%
# calculate metrix for positiv score
query = "SELECT overallScore, RestingHeartRate, maxAvgHeartRate, AsleepAverageStressLevel, sleepFeedback, insight FROM sleep_data WHERE sleepFeedback LIKE 'POSITIVE%';"
df_pos = pd.read_sql(query, connection)
cols = ["overallScore", "RestingHeartRate", "maxAvgHeartRate", "AsleepAverageStressLevel"]
df_pos[cols] = df_pos[cols].apply(pd.to_numeric) # change datatype into numeric
df_pos['AsleepAverageStressLevel'] = df_pos['AsleepAverageStressLevel'].mask(df_pos['AsleepAverageStressLevel'] <= 0)
df_pos["overallSleepScore"] = df_pos["overallScore"]
df_pos.drop(df_pos["overallScore"])
df_pos['RestingHeartRate_Roll'] = df_pos["RestingHeartRate"].rolling(10).mean()
df_pos['AsleepAverageStressLevel_Roll'] = df_pos["AsleepAverageStressLevel"].rolling(10).mean()
df_pos['maxAvgHeartRate_Roll'] = df_pos["maxAvgHeartRate"].rolling(10).mean()
df_pos['overallSleepScore_Roll'] = df_pos["overallScore"].rolling(10).mean()
# Out:
# /tmp/ipykernel_1593/2745481431.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_pos = pd.read_sql(query, connection)

# %%
fig, axes = plt.subplots(ncols=2)
df_neg.plot(ax=axes[0], figsize=(10, 10), legend=False)
df_pos.plot(ax=axes[1], figsize=(10, 10), legend=False)
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
axes[0].set_ylabel('Score',fontdict={'fontsize':16})
axes[0].set_title('Negative sleep score', pad=10, fontdict={'fontsize':16})
axes[1].set_title('Positiv sleep score', pad=10, fontdict={'fontsize':16})

cols = {'overallScore':'purple', 'RestingHeartRate':'orange', 'maxAvgHeartRate':'green','AsleepAverageStressLevel':'red'}
for col, color in cols.items():
    axes[0].axhline(y=np.nanmean(df_neg[col]), color=color, linestyle='--', linewidth=0.7, label='Avg') # add average line
    axes[1].axhline(y=np.nanmean(df_pos[col]), color=color, linestyle='--', linewidth=0.7, label='Avg') # add average line

# %% [markdown]
# * Im Schnitt wird bessser geschlafen, wenn die Herzfrequenz nicht in die Höhe getrieben wurde, z.B. durch Stress oder Sport
# * Die Ruheherzfrequenz korreliert bei negativen Sleep Score mit dem Sleep Score
# * Bei einem schlechten Sleep Score ist die Ruheherzfrequenz tendentiell etwas höher
# * Der Stresspegel ist bei gutem Schlaf niedriger

# %%
query = "SELECT AsleepAverageStressLevel, startDay, insight, sleepFeedback FROM sleep_data;"
df_ = pd.read_sql(query, connection)
df_['AsleepAverageStressLevel'] = df_['AsleepAverageStressLevel'].apply(pd.to_numeric)
print(df_.max())
# Out:
# AsleepAverageStressLevel                             54.0
# startDay                                      ﻿2022-09-03
# insight                            POSITIVE_STRESSFUL_DAY
# sleepFeedback               POSITIVE_SHORT_BUT_RECOVERING
# dtype: object
# /tmp/ipykernel_1651/1027498155.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_ = pd.read_sql(query, connection)

# %%
query = "SELECT overallScore, sleepFeedback, insight FROM sleep_data WHERE insight NOT LIKE 'NONE%';"
df_fb = pd.read_sql(query, connection)
df_fb = df_fb.sort_values('sleepFeedback')
# Out:
# /tmp/ipykernel_1651/2706418128.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_fb = pd.read_sql(query, connection)

# %%
df_fb2 = df_fb[['sleepFeedback', 'insight']].value_counts().reset_index(name='count')
df_fb['count'] = df_fb2['count'] * 20
df_fb['overallScore'] = df_fb['overallScore'].apply(pd.to_numeric)

# %%
ax1 = df_fb.plot.scatter(x='insight', y='sleepFeedback', c='overallScore', cmap='Greens', s='count')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_1651/4037276141.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# [Text(0, 0, ''),
#  Text(1, 0, 'NEGATIVE_STRENUOUS_EXERCISE'),
#  Text(2, 0, 'NEGATIVE_STRESSFUL_DAY'),
#  Text(3, 0, 'NEGATIVE_HIGHLY_STRESSFUL_DAY'),
#  Text(4, 0, 'NEGATIVE_LATE_STRENUOUS_EXERCISE'),
#  Text(5, 0, 'NEGATIVE_VERY_STRENUOUS_EXERCISE'),
#  Text(6, 0, 'NEGATIVE_LATE_EXERCISE'),
#  Text(7, 0, 'POSITIVE_EXERCISE'),
#  Text(8, 0, 'POSITIVE_RESTFUL_DAY'),
#  Text(9, 0, 'POSITIVE_LATE_BED_TIME'),
#  Text(10, 0, 'POSITIVE_STRESSFUL_DAY')]
